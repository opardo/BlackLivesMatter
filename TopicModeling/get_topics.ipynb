# %% [markdown]
# # Black Lives Matter: Topic Modeling

# %% [markdown]
# This analysis was inspired by the [_Topic Modeling with Gensim (Python)_ post](https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/), which can be found on the Machine Learning Plus blog.

# %% [markdown]
# ## Import libraries

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/opardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
# spacy for lemmatization
import spacy

# %%
# Plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'amp'])

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('Data/tw1.csv')
data = df['full_text'].values.tolist()
# Out:
# /Users/opardo/anaconda3/envs/CAP/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,5,7,8,9,15,16,18,19,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Pre-processing tweets

# %% [markdown]
# ### Unique tweets

# %% [markdown]
# Many tweets are repeated or empty. The reason behind can be that they are written by bots, and spread telling the same message.

# %%
original_num = len(data)
print('The total number of tweets is %d.' % (original_num))
# Out:
# The total number of tweets is 293245.

# %%
# Get unique tweets
data = list(set(data))
data = [x for x in data if str(x) != 'nan' and str(x)]
unique_num = len(data)
unique_perc = round(100.0 * unique_num  / original_num)
print('However, the number of unique tweets is %d. That means %d out of 100 of the original ones.' % (unique_num, unique_perc))
# Out:
# However, the number of unique tweets is 83498. That means 28 out of 100 of the original ones.

# %% [markdown]
# In addition, there are some tweets of the form _RT @PaulPannone: Bridge March over Troubled Water http://t.co/Sh5ToZy6PF #AlSharpton #StatenIsland #EricGarner #Verrazano'_.
#
# Therefore, we would like to remove the _RT @PaulPannone:_ part and keep the original text
#
# _Bridge March over Troubled Water http://t.co/Sh5ToZy6PF #AlSharpton #StatenIsland #EricGarner #Verrazano'_
#
# which might be already considered in a different tweet.

# %%
# Remove RT @name:
data = [re.sub("^RT @\S*\s?", "", sent) for sent in data]
data = [re.sub('^"@\S*\s?', "", sent) for sent in data]
data = [re.sub('^“@\S*\s?', "", sent) for sent in data]
data = list(set(data))
data = [x for x in data if str(x) != 'nan' and str(x)]
unique_rt_num = len(data)
unique_rt_perc = round(100.0 * unique_rt_num  / original_num)
print('In consequence, the number of tweets declines to %d. That means %d out of 100 of the original ones.' % (unique_rt_num, unique_rt_perc))
# Out:
# In consequence, the number of tweets declines to 73621. That means 25 out of 100 of the original ones.

# %% [markdown]
# ### URLs

# %% [markdown]
# A lot of tweets include links to other websites, for instance, news and articles. This _URLs_ cannot be considered words and is hard to know where are they pointing, because the text that appears is usually an encrypted version. However, just the fact that the tweet includes a link can be useful for our analysis. Therefore, we will replace any URL with the _http_ word.
#
# That means that
#
# _Bridge March over Troubled Water http://t.co/Sh5ToZy6PF #AlSharpton #StatenIsland #EricGarner #Verrazano_
#
# now becomes
#
# _Bridge March over Troubled Water http #AlSharpton #StatenIsland #EricGarner #Verrazano_.

# %%
# Remove URLs
data = [re.sub("\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*", "http", sent) for sent in data]
data = list(set(data))
data = [x for x in data if str(x) != 'nan' and str(x)]
unique_http_num = len(data)
unique_http_perc = round(100.0 * unique_http_num  / original_num)
print('Accordingly, the number of tweets now reduces to %d. That means %d out of 100 of the original ones.' % (unique_http_num, unique_http_perc))
# Out:
# Accordingly, the number of tweets now reduces to 64105. That means 22 out of 100 of the original ones.

# %% [markdown]
# ### Remove new lines _\n_

# %% [markdown]
# The are some tweets where the user typed _Enter_ to start a new line. This is translated into the _\n_ character, which can create confusion when we are separating words. Consequently, we will replace those characters with ' '.

# %%
data = [re.sub("\n", " ", sent) for sent in data]
data = list(set(data))
data = [x for x in data if str(x) != 'nan' and str(x)]
len(data)
# Out:
# 64075

# %% [markdown]
# ### Decompose into bag of words

# %% [markdown]
# Let's take a tweet in our data:

# %%
tweet = 'News: Man who shot video of Eric Garner in apparent choke hold arrested on firearms charges.'
print(tweet)
# Out:
# News: Man who shot video of Eric Garner in apparent choke hold arrested on firearms charges.

# %% [markdown]
# Now we will decompose this tweet into an array of words, where the order doesn't matter.

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(data))

#Example
tweet_words = list(sent_to_words([tweet]))
print(tweet_words[0])
# Out:
# ['news', 'man', 'who', 'shot', 'video', 'of', 'eric', 'garner', 'in', 'apparent', 'choke', 'hold', 'arrested', 'on', 'firearms', 'charges']

# %% [markdown]
# ### Stop words

# %% [markdown]
# There are commonly used words (such as “the”, “a”, “an”, “in”) which appear that often, that are useless to understand the context we are analyzing. Moreover, since they are common, they make the NLP techniques to spend more time processing, without adding any value. Therefore, we will remove them from every tweet.

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

#Example
tweet_words_nostops = remove_stopwords(tweet_words)
print(tweet_words_nostops[0])
# Out:
# ['news', 'man', 'shot', 'video', 'eric', 'garner', 'apparent', 'choke', 'hold', 'arrested', 'firearms', 'charges']

# %% [markdown]
# ### Bigrams and Trigrams

# %% [markdown]
# There are concepts like _Eric Garner_ or _New York_ which make more sense to be analyzed as a single word, than being split into two. To achieve that we will use the concept of bigrams and trigrams.

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=20) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=20)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Example
tweet_words_bigrams = make_bigrams(tweet_words_nostops)
print(tweet_words_bigrams[0])
# Out:
# ['news', 'man', 'shot', 'video', 'eric_garner', 'apparent_choke', 'hold', 'arrested', 'firearms', 'charges']

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Finally, we would like to tackle one last challenge: The fact that a word used as a singular or plural should be considered the same. Similar case when you conjugate a verb or you use verbs and adjectives with the same origin.
#
# These kinds of problems are solved by _Lemmatization_ , a technique that transforms any single word to its root.

# %%
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# Example
tweet_lemmatized = lemmatization(tweet_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
print(tweet_lemmatized[0])
# Out:
# ['news', 'man', 'shoot', 'video', 'eric_garner', 'apparent_choke', 'hold', 'arrest', 'firearm', 'charge']

# %% [markdown]
# ## Modeling topics

# %% [markdown]
# ### Build corpora

# %% [markdown]
# Once we have the pre-processed tweets we want to model, we need to make them comparable on a mathematical way. To achieve that, we will create as many dimensions as we have unique words in the set of tweets. Then, we will assign to each word the number of times it was mentioned in the tweet (and zero if it didn't appear).

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# Example
print(id2word.doc2bow(tweet_lemmatized[0]))
# Out:
# [(12, 1), (56, 1), (64, 1), (216, 1), (389, 1), (435, 1), (522, 1), (605, 1), (2854, 1), (4363, 1)]

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in [id2word.doc2bow(tweet) for tweet in tweet_lemmatized]]
# Out:
# [[('hold', 1),
#   ('eric_garner', 1),
#   ('shoot', 1),
#   ('arrest', 1),
#   ('man', 1),
#   ('video', 1),
#   ('charge', 1),
#   ('news', 1),
#   ('apparent_choke', 1),
#   ('firearm', 1)]]

# %% [markdown]
# ### LDA Mallet Model

# %% [markdown]
# To model the different topics, we are going to use the Latent Dirichlet Allocation (LDA) technique. Specifically, we are going to use the Mallet implementation, which is a Java-based package for statistical NLP.

# %%
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
mallet_path = 'mallet-2.0.8/bin/mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=10, id2word=id2word)

# %% [markdown]
# This will give us 10 different topics (a fixed parameter we used). Now, we are going to explore the 10 words most representative of each of these topics.

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted=False))
# Out:
# [(0,
#   [('http', 0.23276428102429417),
#    ('man', 0.07124097176625083),
#    ('murder', 0.05991464215364412),
#    ('ericgarner', 0.05808847669074196),
#    ('arrest', 0.038698292843072885),
#    ('video', 0.03237852921864741),
#    ('film', 0.01690741956664478),
#    ('hold', 0.009684832567301379),
#    ('guy', 0.009582239001969797),
#    ('wife', 0.008186966513460276)]),
#  (1,
#   [('ferguson', 0.19323787751173144),
#    ('rt', 0.09391168331127421),
#    ('http', 0.08613083062607789),
#    ('protest', 0.029258412545622267),
#    ('antoniofrench', 0.02825572534392171),
#    ('read', 0.020494926402759395),
#    ('break', 0.018670035695664382),
#    ('fire', 0.014177997032045883),
#    ('mo', 0.014077728311875827),
#    ('tonight', 0.013075041110175269)]),
#  (2,
#   [('mikebrown', 0.1360604355862734),
#    ('happen', 0.036024270674274696),
#    ('make', 0.02923330386562726),
#    ('fuck', 0.024592140159125614),
#    ('shit', 0.0226231616169734),
#    ('thing', 0.021116290283693644),
#    ('hear', 0.016756409226070884),
#    ('good', 0.014184682150606767),
#    ('real', 0.013220284497307723),
#    ('change', 0.012597444346218758)]),
#  (3,
#   [('http', 0.15633547790576724),
#    ('eric_garner', 0.12674808336864815),
#    ('death', 0.10313210309357784),
#    ('chokehold', 0.05851985976807798),
#    ('nypd', 0.05636244558307971),
#    ('ruled_homicide', 0.030897253149439457),
#    ('medical_examiner', 0.020649535770697693),
#    ('homicide', 0.019917555957930422),
#    ('ericgarner', 0.018434333705744117),
#    ('case', 0.01724005085333436)]),
#  (4,
#   [('police', 0.1095022074608125),
#    ('mikebrown', 0.08345822026003483),
#    ('ferguson', 0.06006723642107821),
#    ('officer', 0.05457896229089878),
#    ('time', 0.03485357851674835),
#    ('street', 0.021264530762687837),
#    ('leave', 0.012616954919194782),
#    ('dog', 0.01229292397423954),
#    ('put', 0.012151160435821621),
#    ('victim', 0.009194378063105026)]),
#  (5,
#   [('police', 0.1488045768182609),
#    ('kill', 0.11105742283383907),
#    ('cop', 0.08003633622605771),
#    ('shoot', 0.07220858539979512),
#    ('unarmed', 0.0504841608844392),
#    ('gun', 0.030963103268327567),
#    ('shot', 0.02622779721293415),
#    ('teen', 0.024952163744950618),
#    ('kid', 0.023599219157695354),
#    ('black', 0.022265602350258026)]),
#  (6,
#   [('brown', 0.25133378601222234),
#    ('mike', 0.15415656222718013),
#    ('michael', 0.06396352701522941),
#    ('family', 0.04370938015326414),
#    ('rip', 0.035192550198855366),
#    ('sad', 0.024192453196236297),
#    ('situation', 0.02029294790959356),
#    ('pray', 0.01716946357551654),
#    ('smh', 0.014298186051023377),
#    ('friend', 0.011310505383645359)]),
#  (7,
#   [('mikebrown', 0.10725861310071626),
#    ('michaelbrown', 0.04011444119883158),
#    ('story', 0.03795366331879477),
#    ('news', 0.03169140890720659),
#    ('stl', 0.027389860349725903),
#    ('report', 0.020347325037013326),
#    ('medium', 0.015945740466567965),
#    ('shooting', 0.015885718858789165),
#    ('watch', 0.014685286703213157),
#    ('ferguson', 0.014625265095434357)]),
#  (8,
#   [('people', 0.06689199811350417),
#    ('black', 0.06199889954409684),
#    ('mikebrown', 0.03558795786825971),
#    ('white', 0.026705706649897815),
#    ('stop', 0.025723156736362208),
#    ('life', 0.016899858512812452),
#    ('america', 0.015445684640779752),
#    ('ppl', 0.013755698789498507),
#    ('day', 0.01304826285175287),
#    ('young', 0.012635591888067914)]),
#  (9,
#   [('ferguson', 0.2110602424217978),
#    ('justice', 0.047193594578787086),
#    ('loot', 0.030030453986245285),
#    ('riot', 0.026279168263316055),
#    ('community', 0.02129762216888853),
#    ('call', 0.019986688986144446),
#    ('peace', 0.018474073775285885),
#    ('back', 0.0163564124800839),
#    ('violence', 0.015569852570437448),
#    ('show', 0.013916059939898756)])]

# %% [markdown]
# Finally, we will obtain the coherence score, a metric that will indicate how good the model fit is.

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# Coherence Score:  0.41034813745967796

# %% [markdown]
# ### Choosing the number of topics

# %% [markdown]
# As we mentioned before, the number of topics was fixed to 10. However, we would like to optimize that hyper-parameter as well to improve the model performance. To achieve that we will use the Coherence Score, trying different values, and analyzing which is the one with the best performance.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word, random_seed = 2019)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=22, step=2)

# %%
# Show graph
limit=22; start=2; step=2;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3214
# Num Topics = 4  has Coherence Value of 0.4115
# Num Topics = 6  has Coherence Value of 0.4223
# Num Topics = 8  has Coherence Value of 0.4192
# Num Topics = 10  has Coherence Value of 0.3741
# Num Topics = 12  has Coherence Value of 0.3893
# Num Topics = 14  has Coherence Value of 0.3481
# Num Topics = 16  has Coherence Value of 0.3622
# Num Topics = 18  has Coherence Value of 0.3683
# Num Topics = 20  has Coherence Value of 0.369

# %% [markdown]
# ### Working with the optimal model

# %% [markdown]
# The model we liked the most was the one with 8 topics. Although the 4-theme model has the best performance, the 8-theme balances the diversity of topics with acceptable performance.

# %%
optimal_model = model_list[3]

# %%
# Print the topics
pprint(optimal_model.show_topics(formatted=False))
# Out:
# [(0,
#   [('black', 0.0690938848863144),
#    ('people', 0.05476484652043453),
#    ('mikebrown', 0.024566358049453636),
#    ('happen', 0.023876381957927503),
#    ('white', 0.021806453683349113),
#    ('riot', 0.020314179810978644),
#    ('ferguson', 0.01720126442130261),
#    ('thing', 0.01691243722019865),
#    ('live', 0.016495242374159592),
#    ('call', 0.016190369217438744)]),
#  (1,
#   [('mikebrown', 0.08317006584229966),
#    ('murder', 0.046892564637867354),
#    ('story', 0.030480167014613778),
#    ('make', 0.023317809539103902),
#    ('sad', 0.020025694555965954),
#    ('fuck', 0.01997751726352979),
#    ('shit', 0.01809860285851935),
#    ('stop', 0.01753653444676409),
#    ('read', 0.016412397623253572),
#    ('situation', 0.012718805203147584)]),
#  (2,
#   [('http', 0.1321124822508161),
#    ('eric_garner', 0.09632134440004099),
#    ('death', 0.07837454071699383),
#    ('ericgarner', 0.05545064628987162),
#    ('man', 0.0508248795983195),
#    ('chokehold', 0.044471769648529565),
#    ('nypd', 0.04283225740342248),
#    ('arrest', 0.02760821512742816),
#    ('ruled_homicide', 0.023480157510283546),
#    ('video', 0.02309955645338369)]),
#  (3,
#   [('ferguson', 0.22966111318397872),
#    ('news', 0.02569634832827734),
#    ('loot', 0.024138993884139318),
#    ('stl', 0.022662751650633486),
#    ('report', 0.01661178073747222),
#    ('medium', 0.012929286374770858),
#    ('watch', 0.011907272520805283),
#    ('show', 0.01120970750936846),
#    ('quicktrip', 0.009798355044368379),
#    ('find', 0.007965219084080918)]),
#  (4,
#   [('mikebrown', 0.18488133606797538),
#    ('justice', 0.03808965719308526),
#    ('family', 0.03665722564052479),
#    ('peace', 0.01491031025165218),
#    ('pray', 0.014405703682000195),
#    ('violence', 0.01255005371618322),
#    ('tonight', 0.010840902431878113),
#    ('day', 0.01080834716931992),
#    ('hope', 0.009799134030015953),
#    ('friend', 0.009392193248038545)]),
#  (5,
#   [('http', 0.23469239581148454),
#    ('ferguson', 0.13822423724164637),
#    ('rt', 0.07555785023959728),
#    ('protest', 0.02307233095080592),
#    ('antoniofrench', 0.02271737201310121),
#    ('hand', 0.014892140886429274),
#    ('back', 0.01308507720356895),
#    ('break', 0.012052469384791624),
#    ('follow', 0.011713644944255312),
#    ('fire', 0.011407089498055793)]),
#  (6,
#   [('brown', 0.20382315921963498),
#    ('mike', 0.1250157331655129),
#    ('shoot', 0.05877910635619887),
#    ('michael', 0.0578980490874764),
#    ('unarmed', 0.04109502831969793),
#    ('time', 0.027580239144115795),
#    ('rip', 0.025802391441157962),
#    ('teen', 0.020311516677155445),
#    ('police', 0.016881686595342983),
#    ('shooting', 0.012460667086217746)]),
#  (7,
#   [('police', 0.1961281773669667),
#    ('kill', 0.09285264127466347),
#    ('cop', 0.06727211027261122),
#    ('officer', 0.043549924858200154),
#    ('michaelbrown', 0.0324321703860511),
#    ('gun', 0.025855242958486176),
#    ('put', 0.014333500315110773),
#    ('shot', 0.014155745519771182),
#    ('car', 0.011651018858167833),
#    ('leave', 0.010002747119564339)])]

# %% [markdown]
# ## Exploring the results

# %% [markdown]
# ### Dominant topic in each sentence

# %%
def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# %%
# Show
pd.set_option('display.max_colwidth', -1)
df_dominant_topic.head(20)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0   0            4.0             0.1368
# 1   1            1.0             0.1410
# 2   2            0.0             0.1727
# 3   3            6.0             0.1653
# 4   4            3.0             0.2099
# 5   5            6.0             0.1447
# 6   6            2.0             0.2052
# 7   7            2.0             0.1731
# 8   8            7.0             0.1813
# 9   9            6.0             0.1844
# 10  10           1.0             0.1540
# 11  11           5.0             0.1801
# 12  12           1.0             0.1569
# 13  13           3.0             0.2421
# 14  14           2.0             0.2263
# 15  15           5.0             0.2170
# 16  16           0.0             0.1473
# 17  17           0.0             0.1623
# 18  18           1.0             0.1680
# 19  19           3.0             0.1623
#
#                                                                                      Keywords  \
# 0   mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 1   mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 2   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 3   brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 4   ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 5   brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 6   http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 7   http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 8   police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 9   brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 10  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 11  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 12  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 13  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 14  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 15  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 16  black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 17  black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 18  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 19  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
#
#                                                                                                                                             Text
# 0   MORE Malcolm...LESS Martin! #MichaelBrown
# 1   #MikeBrown ran away for a reason and now you know why
# 2   Sad. So unsurprised at what is unfolding. Angry. Holding hearts in solidarity. Here to stand and and work. #Ferguson  #M…
# 3   But as soon as she opened her mouth about Mike Brown's murder, twitter IMMEDIATELY escorted her to a stadium of seats. Lol I love y'all.
# 4   Find it interesting news outlets were not labeling those white thieves in Boston as "Looters" #Ferguson #MikeBrown http
# 5   I don't see anything wrong with the picture they chose of Mike Brown.  Perhaps bc I don't think what one wears = deserv…
# 6   !RT @NYDailyNews: BREAKING: Eric Garner's death ruled a homicide. http Cause of death:"chokehold." h…
# 7   Coroner rules that police chokehold killed Eric Garner http
# 8   @barrybateman Struggle for the gun? But why did the policeman shoot #MichaelBrown 10 times? Something doesn't add up with #AmericanCops ...
# 9   I don't care what reasons are claimed. Shooting an unarmed teen 10 times is not defense, it's murder #MikeBrown #Ferguson"
# 10  #mikebrown let's protest how will we change this #murder  @smickeymg
# 11  De Blasio zoekt middenweg inzake dood Eric Garner, tussen kritiek op NYPD en zijn afhankelijkheid van de politie  http
# 12  Rip #MikeBrown 😒😩 this world is crazy ✋
# 13  White Supremacism DEPENDS on Terrorism, Murder.   Frances Cress Welsing, MD, discussion of Elliot Rodger.  #Ferguson #MikeBrow…
# 14  should have big audience in Staten Island "@InsideCityHall: PBA Pres. Patrick Lynch talks to Errol about death of Eric Garner. Stay tuned.."
# 15  #OpFerguson #MikeBrown MT @AntonioFrench The international hacker group Anonymous has joined the #Ferguson protest  http
# 16  I hate knowing someone who was close to Mike Brown because I can't really speak on the issue
# 17  If you believe racism played no role in #Ferguson's murder, you're part of the problem.
# 18  In Oakland, smashing shit up did lead to the prosecution of a murderous pig. Same in LA. Loot intelligently, not Black owned. #Ferguson
# 19  Attacking our own neighborhoods destroying the businesses we can call our own &amp; ruining what keeps us moving This is di…

# %% [markdown]
# ### Most representative tweets

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(10)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0   0.0        0.3164
# 1   0.0        0.3164
# 2   0.0        0.3056
# 3   0.0        0.2996
# 4   0.0        0.2944
# 5   0.0        0.2944
# 6   0.0        0.2799
# 7   0.0        0.2720
# 8   0.0        0.2703
# 9   0.0        0.2664
# 10  1.0        0.2852
# 11  1.0        0.2817
# 12  1.0        0.2817
# 13  1.0        0.2711
# 14  1.0        0.2639
# 15  1.0        0.2603
# 16  1.0        0.2560
# 17  1.0        0.2555
# 18  1.0        0.2542
# 19  1.0        0.2523
# 20  2.0        0.3201
# 21  2.0        0.3043
# 22  2.0        0.3025
# 23  2.0        0.3003
# 24  2.0        0.2985
# 25  2.0        0.2897
# 26  2.0        0.2897
# 27  2.0        0.2890
# 28  2.0        0.2879
# 29  2.0        0.2872
# 30  3.0        0.2810
# 31  3.0        0.2693
# 32  3.0        0.2646
# 33  3.0        0.2639
# 34  3.0        0.2621
# 35  3.0        0.2609
# 36  3.0        0.2597
# 37  3.0        0.2574
# 38  3.0        0.2567
# 39  3.0        0.2513
# 40  4.0        0.2910
# 41  4.0        0.2897
# 42  4.0        0.2859
# 43  4.0        0.2826
# 44  4.0        0.2782
# 45  4.0        0.2703
# 46  4.0        0.2681
# 47  4.0        0.2653
# 48  4.0        0.2609
# 49  4.0        0.2562
# 50  5.0        0.2934
# 51  5.0        0.2886
# 52  5.0        0.2818
# 53  5.0        0.2764
# 54  5.0        0.2737
# 55  5.0        0.2711
# 56  5.0        0.2700
# 57  5.0        0.2693
# 58  5.0        0.2675
# 59  5.0        0.2675
# 60  6.0        0.3035
# 61  6.0        0.3035
# 62  6.0        0.2979
# 63  6.0        0.2944
# 64  6.0        0.2782
# 65  6.0        0.2731
# 66  6.0        0.2700
# 67  6.0        0.2685
# 68  6.0        0.2646
# 69  6.0        0.2628
# 70  7.0        0.2782
# 71  7.0        0.2711
# 72  7.0        0.2693
# 73  7.0        0.2681
# 74  7.0        0.2664
# 75  7.0        0.2603
# 76  7.0        0.2603
# 77  7.0        0.2585
# 78  7.0        0.2579
# 79  7.0        0.2573
#
#                                                                                      Keywords  \
# 0   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 1   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 2   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 3   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 4   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 5   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 6   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 7   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 8   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 9   black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 10  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 11  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 12  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 13  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 14  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 15  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 16  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 17  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 18  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 19  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 20  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 21  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 22  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 23  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 24  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 25  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 26  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 27  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 28  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 29  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 30  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 31  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 32  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 33  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 34  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 35  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 36  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 37  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 38  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 39  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 40  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 41  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 42  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 43  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 44  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 45  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 46  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 47  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 48  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 49  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 50  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 51  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 52  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 53  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 54  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 55  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 56  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 57  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 58  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 59  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 60  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 61  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 62  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 63  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 64  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 65  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 66  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 67  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 68  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 69  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 70  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 71  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 72  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 73  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 74  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 75  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 76  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 77  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 78  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
# 79  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
#
#                                                                                                                                                     Text
# 0   black lives matter. black lives matter. black lives matter. black lives matter. black lives matter. black lives matter. black lives matter.
# 1   BLACK LIFE MATTERS. BLACK LIVES MATTER. BLACK LIFE MATTERS. BLACK LIVES MATTER. BLACK LIFE MATTERS. BLACK LIVES MATTER. Ad infinitum.
# 2   black lives matter. black lives matter. black lives matter. black lives matter. black lives matter. black lives matter. black…
# 3   Bitch “@mamacitamusings: BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MAT
# 4   BLACK LIFE MATTERS. BLACK LIVES MATTER. BLACK LIFE MATTERS. BLACK LIVES MATTER. BLACK LIFE MATTERS. BLACK LIVES MATTER.…
# 5   BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER. BLACK LIVES MATTER.
# 6   RT @bwahby: "Returning hate for hate multiplies hate, adding deeper darkness to a night already devoid of stars." Dr MLK #…
# 7   "Returning hate for hate multiplies hate, adding deeper darkness to a night already devoid of stars." Dr MLK #Ferguson
# 8   "Returning hate for hate multiplies hate, adding deeper darkness to a night already devoid of stars." - Dr. Martin Luther Ki…
# 9   Black lives matter.  Black children matter.  Black children are not adults. They are children.  Black people are not di…
# 10  “İnsanlar birbirine yardımdan el çektikleri gün insanlık yok olur. Karşılıklı dayanışma olmazsa toplumlar olmaz.”  Walter Scott
# 11  "İnsanlar birbirine yardımdan el çektikleri gün insanlık yok olur. Karşılıklı dayanışma olmazsa toplumlar olmaz."Walter Scott
# 12  “İnsanlar birbirine yardımdan el çektikleri gün İNSANLIK yok olur. Karşılıklı dayanışma olmazsa, toplumlar olmaz.”   Walter Scott
# 13  #MikeBrown jus read the story on this. Sad sad sad smh. It ain't safe no where. U can't even trust the ones that's suppose to protect u 👎
# 14  @kekepalmer rather code her tweets in defense of white ppl than interrogate the racist power structure that got #MikeBrown murdered
# 15  İnsanlar birbirine yardımdan el geçtikleri gün insanlık yok olur. Karşılıklı dayanışma olmazsa toplumlar olmaz. Walter SCOTT
# 16  #MikeBrown To act abnormal in an abnormal situation IS fucking normal.  It's not normal and should never be normal to be harassed, (1/2)
# 17  When will we stop hiring insecure people who perceive their badge as ultimate power to "protect and serve"?  #MikeBrown
# 18  White-privilege apologist internet trolls saying, "Wait for details before you jump to conclusions." You need more details? #Ferguson
# 19  @drboycewatkins1 @SAANETER @Mr_iKeepitreal @TheBlackDot1 @CombatJackShow @ZoWilliams Make the diaspora aware of the injustice of #MikeBrown
# 20  NYPD Arrest Wife of Man Who Filmed Eric Garner Video - NYPD Arrest Wife of Man Who Filmed Eric Garner Video... http
# 21  @TheRevAl Sharpton is Holding a Rally on Ramsay Orta's Arrest at the @NationalAction. Orta filmed the video of #EricGarner's Arrest #SI
# 22  Man who taped Eric Garner arrested. Now his wife? #Fishy @metronewyork Wife of man who taped Garner charged w/assault http
# 23  Wife Of Man Who Filmed Deadly NYPD Chokehold Of Eric Garner Arrested: The wife of Ramsay Orta — who videotaped... http
# 24  Man Who Taped Fatal Eric Garner NYPD Chokehold Video Arrested  The man who videotaped the fatal chokehold death of Eric Gar…
# 25  Man Who Taped Fatal Eric Garner NYPD Chokehold Video Arrested  The man who videotaped the fatal chokehold death of Eric Garner by the NYP...
# 26  Official: NYPD chokehold caused NYC man's death: A medical examiner ruled the death of Eric Garner a homicide after an NYPD officer p...
# 27  Man Who Taped Fatal Eric Garner NYPD Chokehold Video Arrested:  The man who videotaped the fatal chokehold dea... http
# 28  HOMICIDE: Medical Examiner Rules NYPD Chokehold Killed Eric Garner: HOMICIDE: Medical Examiner Rules NYPD Chok... http
# 29  #Plug Man Who Taped Fatal Eric Garner NYPD Chokehold Video Arrested: The man who videotaped the fata... http #DopeDrop
# 30  @Nettaaaaaaaa: THEY IN CLOCK TOWER LOOTIN NOW. Citi Trendz, Ross. Prime Sol. #STL #FERGUSON
# 31  No...SMDH “@iMDRW: RT @Nettaaaaaaaa: THEY IN CLOCK TOWER LOOTIN NOW. Citi Trendz, Ross. Prime Sol. #STL #FERGUSON”
# 32  Walmarts, gas stations, fast food joints and even bus stops are being looted, burned and/or destroyed. Stunning. #Ferguson #FergusonShooting
# 33  BREAKING: AutoTire windows smashed. Rims and tires stolen. This is OUTSIDE the secure zone. #Ferguson @kmoxnews http
# 34  @akahnnyc @Athena5000 I watched 1 of my dad's stores go up in flames on TV. Helped clean up &amp; rebuild it.  Protest YES.  Loot NO! #Ferguson
# 35  Walmarts, gas stations, fast food joints and even bus stops are being looted, burned and/or destroyed. Stunning. #Ferguson #…
# 36  THEY IN CLOCK TOWER LOOTIN NOW. Citi Trendz, Ross. Prime Sol. #STL #FERGUSON
# 37  They broke in the hair store RT @Pacific_Tomb: Crying. RT @DLoesch: Salon looted via KTVI http h/t @AmPowerBlog #Ferguson
# 38  BREAKING: AutoTire windows smashed. Rims and tires stolen. This is OUTSIDE the secure zone. #Ferguson @kmoxnews http://…
# 39  Watching the Auto parts store be looted in #Ferguson. Looks like a small business. Those looting are robbing their city of so much more.
# 40  C'est vraiment grave ce qu'il se passe aux États Unis #TrayvonMartin #DariusSimmons #EricGarner #SeanBell #JohnCrawford #MikeBrown .. RIP👼🇺🇸
# 41  C'est vraiment grave ce qu'il se passe aux États Unis #TrayvonMartin #DariusSimmons #EricGarner #SeanBell #JohnCrawford #Mike…
# 42  Have a lovely day,tweeps Remember #MikeBrown Remember #Yazidis  Remember #Syria #Gaza #Israel  Remember the world's children deserve to live
# 43  Have a lovely day,tweeps Remember #MikeBrown Remember #Yazidis  Remember #Syria #Gaza #Israel  Remember the world's children de…
# 44  Praying. Praying for peace and comfort - for the Spirit of God's loving grace to surround #MikeBrown family. Praying for …
# 45  Praying. Praying for peace and comfort - for the Spirit of God's loving grace to surround #MikeBrown family. Praying for the neighborhood.
# 46  WORLD PLS TREND #shameonusa #icc #gaza #ferguson #shameonusa #icc #gaza #ferguson #shameonusa #icc #gaza #ferguson #shameonusa #bds
# 47  #tonystewart #MikeBrown #HARRYSINGDONTLETMEGOLIVE #CommunityShield Kevin Ward Pat Rice #AFCvMCFC TCAs Luke Bryan Watkins Glen
# 48  Loss of #MikeBrown is tragic &amp; devastating to his family, friends &amp; our entire community. We must not let more violence carry the day.
# 49  @MrCouture @trueblackpower Was education going 2 save Eric Garner? Trayvon, Jordan, Renisha, 7 Aiyana, Dione 16. Jonathan college-10 bullets
# 50  @Frmaza que tuit tan despectivo el suyo, el digno pueblo de #Ferguson no está "robando", esta luchando contra una policía racista y criminal
# 51  @Frmaza que tuit tan despectivo el suyo, el digno pueblo de #Ferguson no está "robando", esta luchando contra una policía …
# 52  😔RT @ThisIsntPat: dvnklwo’;jfkdb;jowpkj RT @Simplemachines_: Why though? RT @DarthVinThaGod: Right now in #Ferguson http
# 53  😔RT @ThisIsntPat: dvnklwo’;jfkdb;jowpkj RT @Simplemachines_: Why though? RT @DarthVinThaGod: Right now in #Ferguson http.…
# 54  @ufez @dantsypants RT @AntonioFrench: #BREAKING: international hacker group Anonymous has joined #Ferguson protest htt…
# 55  Looks like the 60's. RT @AllSabotage: Crazy. RT @Pacino718: RT @BlogXilla: They've brought the dogs out in #Ferguson http
# 56  @ufez @dantsypants RT @AntonioFrench: #BREAKING: international hacker group Anonymous has joined #Ferguson protest http
# 57  RT @MissKristilyn: RT @AntonioFrench: #BREAKING: The int'l hacker group Anonymous has joined the #Ferguson protest http…
# 58  Jeesus RT @MVPGO: Wooooooow RT @AntonioFrench: They've brought the dogs out in #Ferguson http @JayBattle_01
# 59  Looks like the 60's. RT @AllSabotage: Crazy. RT @Pacino718: RT @BlogXilla: They've brought the dogs out in #Ferguson https:/…
# 60  "Semangat manusia tidak bisa dilumpuhkan. Jika Anda masih bisa bernapas, maka Anda masih bisa mempunyai impian." [Mike Brown]
# 61  Semangat manusia tidak bisa dilumpuhkan. Jika Anda masih bisa bernapas, maka Anda masih bisa mempunyai impian ~ mike brown
# 62  "Semangat manusia tidak bisa dilumpuhkan. Jika Anda masih bisa bernapas, maka Anda masih bisa mempunyai impian." [Mike…
# 63  Byron Scott replaced Mike Brown, who replaced Byron Scott. Byron Scott coaches the Lakers. Replaced by Mike Brown?
# 64  Police shot an unarmed 18 year old boy 8 times because they suspected him of stealing candy smfh! 🙏👼 Rip Mike Brown 👼🙏
# 65  Eric Harris y Dylan Klebold: autores de Masacre de Columbine Cho Seung-Hui: Virginia Tech Adam Lanza: Sandy Hook Todos produ…
# 66  Rip 13 yr old Darius Simmons Rip 17 yr old Michael Brown Rip Amadou Diallo shot 41 times Rip Trayvon Martin Rip Jordan Da…
# 67  Outrage in Missouri as 18yr old unarmed boy is shot dead by police 18 year old Michael Brown (pictured above) wa... http
# 68  Rip 13 yr old Darius Simmons Rip 17 yr old Michael Brown Rip Amadou Diallo shot 41 times Rip Trayvon Martin Rip Jordan Davis
# 69  AG Eric Holder has instructed attorneys in dept civil rights division to monitor developments related to #MikeBrown shooting @TheJusticeDept
# 70  Police claim #MichaelBrown "physically assaulted" officer in police car, &amp; there was a struggle over officer's weapon b4 officer killed him.
# 71  Come onnnn mann #LIES~&gt;“@tjholmes: Police chief says there was a struggle in the car over the officer’s gun. #MichaelBrown”
# 72  The police kill the police kill the police  kill the police kill the police...  The police kill! Get it? #Ferguson #FergusonShooting
# 73  MURDER of Michael Brown, Cops Lie! said "there was a struggle over cops gun &amp; 1 shot fired in car &amp; 1 shot out of the car" Liar! Liar! Liar!
# 74  Police claim #MichaelBrown "physically assaulted" officer in police car, &amp; there was a struggle over officer's weapon b4 offi…
# 75  police claim that mike brown entered a police car and struggled w an officer over his weapon. he was pushed out of the car and shot
# 76  Police chief: Missouri teen killed by police ofcr struggld ovr the officer's weapon. ::Late 2 the party n  spreadn lies #ferguson
# 77  @stlcountypd Police chief: there's about 35 feet between officer's car and where #MichaelBrown was shot by the officer.
# 78  mt @tjholmes Police dept in CA that outfitted all officers w/vid cameras saw an 88% drop in complaints &amp; 60% drop in use of force. #ferguson
# 79  mt @MichaelSkolnik St Louis County Police state that allegedly #MikeBrown attempted to get the police officer's weapon while he was in car.

# %% [markdown]
# ### Topic Distribution

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts().sort_index()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4).sort_index()

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']].drop_duplicates()\
    .sort_values('Dominant_Topic').reset_index(drop=True)

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
#      Dominant_Topic  \
# 0.0  0.0
# 1.0  1.0
# 2.0  2.0
# 3.0  3.0
# 4.0  4.0
# 5.0  5.0
# 6.0  6.0
# 7.0  7.0
#
#                                                                                 Topic_Keywords  \
# 0.0  black, people, mikebrown, happen, white, riot, ferguson, thing, live, call
# 1.0  mikebrown, murder, story, make, sad, fuck, shit, stop, read, situation
# 2.0  http, eric_garner, death, ericgarner, man, chokehold, nypd, arrest, ruled_homicide, video
# 3.0  ferguson, news, loot, stl, report, medium, watch, show, quicktrip, find
# 4.0  mikebrown, justice, family, peace, pray, violence, tonight, day, hope, friend
# 5.0  http, ferguson, rt, protest, antoniofrench, hand, back, break, follow, fire
# 6.0  brown, mike, shoot, michael, unarmed, time, rip, teen, police, shooting
# 7.0  police, kill, cop, officer, michaelbrown, gun, put, shot, car, leave
#
#      Num_Documents  Perc_Documents
# 0.0  8227           0.1284
# 1.0  8114           0.1266
# 2.0  9791           0.1528
# 3.0  8029           0.1253
# 4.0  7836           0.1223
# 5.0  6801           0.1061
# 6.0  9349           0.1459
# 7.0  5928           0.0925
